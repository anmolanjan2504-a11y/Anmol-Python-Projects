# %%
import pandas as pd
Q=pd.read_csv(r"C:\Users\anmol\Downloads\repayment.csv" , encoding= "UTF-8")
print(Q)
# Out:
#       SL No: Costomer      Month         Amount  Unnamed: 4
# 0        1.0       A1  12-Jan-04  331844.007400         NaN
# 1        2.0       A1   3-Jan-04  441139.807300         NaN
# 2        3.0       A1  15-Jan-04   32480.004010         NaN
# 3        4.0       A1  25-Jan-04   90636.966530         NaN
# 4        5.0       A1  17-Jan-05    1581.969829         NaN
# ...      ...      ...        ...            ...         ...
# 1518     NaN      NaN        NaN            NaN         NaN
# 1519     NaN      NaN        NaN            NaN         NaN
# 1520     NaN      NaN        NaN            NaN         NaN
# 1521     NaN      NaN        NaN            NaN         NaN
# 1522     NaN      NaN        NaN            NaN         NaN
#
# [1523 rows x 5 columns]

# %%
import pandas as pd
B= pd.read_csv(r"C:\Users\anmol\Downloads\Credit Banking_Project1.csv" , encoding= "UTF-8")
print(B)
# Out:
#     Sl No: Customer      Age        City Credit Card Product            Limit  \
# 0        1       A1   0.9285   BANGALORE                Gold  INR 5,00,000.00
# 1        2       A2  35.5346    CALCUTTA              Silver  INR 1,00,000.00
# 2        3       A3  11.5593      COCHIN            Platimum    INR 10,000.00
# 3        4       A4  45.8203      BOMBAY            Platimum    INR 10,001.00
# 4        5       A5  69.6639   BANGALORE            Platimum    INR 10,002.00
# ..     ...      ...      ...         ...                 ...              ...
# 95      96      A96  29.6316     CHENNAI              Silver  INR 1,00,000.00
# 96      97      A97  20.6118  TRIVANDRUM            Platimum    INR 10,000.00
# 97      98      A98  40.5390    CALCUTTA            Platimum    INR 10,001.00
# 98      99      A99  21.5887    CALCUTTA            Platimum    INR 10,002.00
# 99     100     A100  23.6076      COCHIN              Silver  INR 1,00,000.00
#
#    Company        Segment
# ...

# %%
import pandas as pd
W=pd.read_csv(r"C:\Users\anmol\Downloads\spend.csv" , encoding= "UTF-8")
print(W)
# Out:
#       Sl No: Costomer      Month        Type  Amount
# 0          1       A1  12-Jan-04   JEWELLERY  473776
# 1          2       A1   3-Jan-04       PETRO  335579
# 2          3       A1  15-Jan-04     CLOTHES  371041
# 3          4       A1  25-Jan-04        FOOD  141178
# 4          5       A1  17-Jan-05      CAMERA  398404
# ...      ...      ...        ...         ...     ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  195841
# 1496    1497      A68  25-Mar-06  BUS TICKET  284263
# 1497    1498      A69  31-Mar-06  BUS TICKET  206552
# 1498    1499      A70  23-Mar-06  BUS TICKET   41025
# 1499    1500      A71  24-Mar-06  BUS TICKET  101398
#
# [1500 rows x 5 columns]

# %%
Q.rename(columns={"Costomer":"Customer"},inplace= True)
Q
# Out:
#       SL No: Customer      Month         Amount  Unnamed: 4
# 0        1.0       A1  12-Jan-04  331844.007400         NaN
# 1        2.0       A1   3-Jan-04  441139.807300         NaN
# 2        3.0       A1  15-Jan-04   32480.004010         NaN
# 3        4.0       A1  25-Jan-04   90636.966530         NaN
# 4        5.0       A1  17-Jan-05    1581.969829         NaN
# ...      ...      ...        ...            ...         ...
# 1518     NaN      NaN        NaN            NaN         NaN
# 1519     NaN      NaN        NaN            NaN         NaN
# 1520     NaN      NaN        NaN            NaN         NaN
# 1521     NaN      NaN        NaN            NaN         NaN
# 1522     NaN      NaN        NaN            NaN         NaN
#
# [1523 rows x 5 columns]

# %%
W.rename(columns={"costomer":"Customer"},inplace= True)
W
# Out:
#       Sl No: Costomer      Month        Type  Amount
# 0          1       A1  12-Jan-04   JEWELLERY  473776
# 1          2       A1   3-Jan-04       PETRO  335579
# 2          3       A1  15-Jan-04     CLOTHES  371041
# 3          4       A1  25-Jan-04        FOOD  141178
# 4          5       A1  17-Jan-05      CAMERA  398404
# ...      ...      ...        ...         ...     ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  195841
# 1496    1497      A68  25-Mar-06  BUS TICKET  284263
# 1497    1498      A69  31-Mar-06  BUS TICKET  206552
# 1498    1499      A70  23-Mar-06  BUS TICKET   41025
# 1499    1500      A71  24-Mar-06  BUS TICKET  101398
#
# [1500 rows x 5 columns]

# %%
B.rename(columns={"costomer":"Customer"},inplace= True)
B
# Out:
#     Sl No: Customer      Age        City Credit Card Product            Limit  \
# 0        1       A1   0.9285   BANGALORE                Gold  INR 5,00,000.00
# 1        2       A2  35.5346    CALCUTTA              Silver  INR 1,00,000.00
# 2        3       A3  11.5593      COCHIN            Platimum    INR 10,000.00
# 3        4       A4  45.8203      BOMBAY            Platimum    INR 10,001.00
# 4        5       A5  69.6639   BANGALORE            Platimum    INR 10,002.00
# ..     ...      ...      ...         ...                 ...              ...
# 95      96      A96  29.6316     CHENNAI              Silver  INR 1,00,000.00
# 96      97      A97  20.6118  TRIVANDRUM            Platimum    INR 10,000.00
# 97      98      A98  40.5390    CALCUTTA            Platimum    INR 10,001.00
# 98      99      A99  21.5887    CALCUTTA            Platimum    INR 10,002.00
# 99     100     A100  23.6076      COCHIN              Silver  INR 1,00,000.00
#
#    Company        Segment
# ...

# %%
mode= B[B["Age"]>18]["Age"].mean()
mode
# Out:
# np.float64(49.29243076923076)

# %%
median= B[B["Age"]<18]["Age"].mean()
mode
# Out:
# np.float64(49.29243076923076)

# %%
spent=pd.DataFrame(df2.groupby('Customer')['Amount].sum()).reset_index(drop=False)
# Out:
#   Cell In[6], line 1
#     spent=pd.DataFrame(df2.groupby('Customer')['Amount].sum()).reset_index(drop=False)
#                                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
seg_max = pd.merge(max_spending, off)
